# %% [markdown]
# <a href="https://colab.research.google.com/github/SuryaSivamani/Weather-Knowledge-Graph/blob/main/Weather_Knowledge_Graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# Base folder
project_root = "/content/Weather-Knowledge-Graph"

# Subfolders
folders = ["data", "notebooks", "scripts"]

for folder in folders:
    os.makedirs(os.path.join(project_root, folder), exist_ok=True)

print("Folders created successfully!")
# Out:
# Folders created successfully!

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Files to create
files = [
    "README.md",
    "requirements.txt",
    "scripts/insert_weather.py",
    "scripts/queries.py",
    "notebooks/.gitkeep"  # keeps folder in Git
]

for file in files:
    path = os.path.join(project_root, file)
    with open(path, "w") as f:
        pass  # create empty file

print("Files created successfully!")
# Out:
# Files created successfully!

# %%
# !apt-get install tree -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 2 not upgraded.
# Need to get 47.9 kB of archives.
# After this operation, 116 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tree amd64 2.0.2-1 [47.9 kB]
# Fetched 47.9 kB in 1s (67.6 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 117540 files and directories currently installed.)
# Preparing to unpack .../tree_2.0.2-1_amd64.deb ...
# Unpacking tree (2.0.2-1) ...
# Setting up tree (2.0.2-1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !tree /content/Weather-Knowledge-Graph
# Out:
# /content/Weather-Knowledge-Graph
# ├── data
# ├── notebooks
# ├── README.md
# ├── requirements.txt
# └── scripts
#     ├── insert_weather.py
#     └── queries.py
#
# 3 directories, 4 files

# %%
# !pip install -r /content/Weather-Knowledge-Graph/requirements.txt
# Out:
# ...
#   Using cached neo4j-5.12.0.tar.gz (190 kB)
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# !pip install neo4j==4.4.10 pandas==2.1.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 71.7 MB/s eta 0:00:00
# ...
#   Created wheel for neo4j: filename=neo4j-4.4.10-py3-none-any.whl size=111169 sha256=72189a95ba92894ec03dc0c4b29257bf8ddf3c1eceebc12eda9557844381789e
#   Stored in directory: /root/.cache/pip/wheels/ea/8b/84/809c8b51467d8f4568e66a176f41eb949680d60d715e18a812
# Successfully built neo4j
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.1.1 which is incompatible.
# ...

# %%
# !python /content/Weather-Knowledge-Graph/scripts/insert_weather.py
# Out:
# Weather graph created!
# Failed to write data to connection ResolvedIPv4Address(('34.28.32.244', 7687)) (IPv4Address(('34.28.32.244', 7687)))
# Failed to write data to connection IPv4Address(('p-d1103c36-1287-0001.production-orch-0336.neo4j.io', 7687)) (IPv4Address(('34.28.32.244', 7687)))

# %%
# !python /content/Weather-Knowledge-Graph/scripts/queries.py
# Out:
# Weather causing Flight Delay: [{'Weather': 'Snow', 'Occurrences': 8}, {'Weather': 'Storm', 'Occurrences': 7}, {'Weather': 'Rain', 'Occurrences': 6}, {'Weather': 'Heatwave', 'Occurrences': 3}]
# Storms by City: [{'City': 'Dallas', 'StormCount': 6}, {'City': 'New York', 'StormCount': 5}, {'City': 'San Francisco', 'StormCount': 5}, {'City': 'Chicago', 'StormCount': 2}]
# ...
